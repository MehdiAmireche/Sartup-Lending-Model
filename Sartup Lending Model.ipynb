# %% [markdown]
# # Startup Lending Model (Project 2)
#
# Insert a description of the model
#
# - [**Setup**](#Setup): Runs any imports and other setup
# - [**Inputs**](#Inputs): Defines the inputs for the model

# %% [markdown]
# ## Setup
#
# Setup for the later calculations are here. The necessary packages are imported.

# %%
from dataclasses import dataclass
import pandas as pd
# %matplotlib inline
import numpy_financial as npf

# %% [markdown]
# ## Inputs
#
# All of the inputs for the model are defined here. A class is constructed to manage the data, and an instance of the class containing the default inputs is created.

# %%
@dataclass
class ModelInputs:
    price_machine: float = 1000000
    loan_life: tuple = (5, 10, 20)
    initial_default: tuple = (0.1, 0.2, 0.3)
    default_decay: float = 0.9
    final_default: float = 0.4
    recovery_rate: float = 0.4
    interest_rates: tuple = (0.30, 0.35, 0.40)
    num_iterations: int = 1000
    case_names: tuple = ('Low Default', 'Base Case', 'High Default')
        
model_data = ModelInputs()
model_data

data = ModelInputs()

# %% [markdown]
# ## Default Probability

# %%
import numpy as np
import pandas as pd
from dataclasses import dataclass
from typing import List
import numpy_financial as npf

@dataclass
class ModelInputs:
    """
    Model inputs with internal randomness integrated through tuples
    """
    price_machine: int = 1000000
    loan_life: tuple = (5, 10, 20)  # Different loan terms to evaluate
    initial_default: tuple = (0.1, 0.2, 0.3)  # p_default_1 scenarios
    default_decay: float = 0.9  # Decay_default
    final_default: float = 0.4  # p_default_n
    recovery_rate: float = 0.4  # r_recovery
    interest_rates: tuple = (0.30, 0.35, 0.40)  # Interest rates to evaluate (30%, 35%, 40%)

def calculate_default_probabilities(initial_prob: float, decay: float, final_prob: float, life: int) -> List[float]:
    """Calculate default probabilities for each year of the loan"""
    probs = []
    current_prob = initial_prob
    
    for year in range(1, life + 1):
        if year == life:  # Final year has special probability
            probs.append(final_prob)
        else:
            probs.append(current_prob)
            current_prob = current_prob * decay
    
    return probs

def calculate_expected_irr(price_machine: int, life: int, interest_rate: float, 
                         default_probs: List[float], recovery_rate: float) -> float:
    """Calculate expected IRR using analytical approach"""
    
    # Calculate cumulative survival probabilities
    survival_probs = [1.0]  # Start with 100% survival at time 0
    for i, default_prob in enumerate(default_probs):
        if i == 0:
            survival_probs.append(1 - default_prob)
        else:
            survival_probs.append(survival_probs[-1] * (1 - default_prob))
    
    scenarios = []
    
    # No default scenario
    no_default_prob = survival_probs[-1]
    no_default_cash_flows = [-price_machine]  # Initial investment
    # Regular interest payments
    for year in range(1, life):
        no_default_cash_flows.append(price_machine * interest_rate)
    # Final payment: principal + interest
    no_default_cash_flows.append(price_machine * (1 + interest_rate))
    
    no_default_irr = npf.irr(no_default_cash_flows)
    scenarios.append((no_default_prob, no_default_irr))
    
    # Default scenarios for each year
    for default_year in range(1, life + 1):
        # Probability of defaulting in this specific year
        if default_year == 1:
            default_year_prob = default_probs[0]
        else:
            # Survive to previous year * default in this year
            default_year_prob = survival_probs[default_year - 1] * default_probs[default_year - 1]
        
        # Build cash flows for default scenario
        cash_flows = [-price_machine]  # Initial investment
        
        # Regular payments before default
        for year in range(1, default_year):
            cash_flows.append(price_machine * interest_rate)
        
        # Default year and year after: no payments
        cash_flows.extend([0, 0])
        
        # Recovery payment 2 years after default
        cash_flows.append(recovery_rate * price_machine)
        
        default_irr = npf.irr(cash_flows)
        scenarios.append((default_year_prob, default_irr))
    
    # Calculate expected IRR
    expected_irr = sum(prob * irr for prob, irr in scenarios if not np.isnan(irr))
    
    return expected_irr

def run_analysis(inputs: ModelInputs) -> pd.DataFrame:
    """Run the complete analysis and return DataFrame with required columns"""
    results = []
    
    for interest_rate in inputs.interest_rates:
        for life in inputs.loan_life:
            for initial_default in inputs.initial_default:
                
                # Calculate default probabilities for this scenario
                default_probs = calculate_default_probabilities(
                    initial_default, inputs.default_decay, inputs.final_default, life
                )
                
                # Calculate expected IRR
                expected_irr = calculate_expected_irr(
                    inputs.price_machine, life, interest_rate, default_probs, inputs.recovery_rate
                )
                
                results.append({
                    'Interest Rate': interest_rate,
                    'Loan Life': life,
                    'Initial Default Probability': initial_default,
                    'IRR': expected_irr
                })
    
    return pd.DataFrame(results)

def verify_specific_scenarios(inputs: ModelInputs):
    """Verify against expected results from document"""
    print("Verification Scenarios (5 years, 20% interest, 20% initial default):")
    print("-" * 60)
    
    life = 5
    interest_rate = 0.20
    initial_default = 0.2
    price_machine = inputs.price_machine
    recovery_rate = inputs.recovery_rate
    
    # No default
    cash_flows = [-price_machine] + [price_machine * interest_rate] * (life - 1)
    cash_flows.append(price_machine * (1 + interest_rate))
    irr_no_default = npf.irr(cash_flows)
    print(f"No Default: {irr_no_default:.2%}")
    
    # Default scenarios
    for default_year in range(1, life + 1):
        cash_flows = [-price_machine]
        
        # Regular payments before default
        for year in range(1, default_year):
            cash_flows.append(price_machine * interest_rate)
        
        # Default and recovery
        cash_flows.extend([0, 0, recovery_rate * price_machine])
        
        irr = npf.irr(cash_flows)
        print(f"Default in t = {default_year}: {irr:.2%}")

# Main execution
def main():
    print("Probabilistic Loan Pricing Analysis")
    print("=" * 50)
    
    inputs = ModelInputs()
    
    # Show verification scenarios first
    verify_specific_scenarios(inputs)
    print("\n" + "=" * 50)
    
    # Run main analysis
    print("Running main analysis...")
    irr_df = run_analysis(inputs)
    
    # Format the output for better display
    irr_df_display = irr_df.copy()
    irr_df_display['Interest Rate'] = irr_df_display['Interest Rate'].apply(lambda x: f"{x:.0%}")
    irr_df_display['Initial Default Probability'] = irr_df_display['Initial Default Probability'].apply(lambda x: f"{x:.0%}")
    irr_df_display['IRR'] = irr_df_display['IRR'].apply(lambda x: f"{x:.2%}")
    
    print("\nMain Results:")
    print(irr_df_display.to_string(index=False))
    
    # Also show summary by interest rate
    print("\n" + "=" * 50)
    print("Summary by Interest Rate:")
    summary = irr_df.groupby('Interest Rate')['IRR'].agg(['mean', 'min', 'max'])
    summary_display = summary.copy()
    summary_display = summary_display.applymap(lambda x: f"{x:.2%}")
    summary_display.index = [f"{x:.0%}" for x in summary.index]
    print(summary_display)
    
    return irr_df

# Execute the analysis
irr_df = main()
# Out:
# Probabilistic Loan Pricing Analysis
# ...
# Verification Scenarios (5 years, 20% interest, 20% initial default):
# ------------------------------------------------------------
# No Default: 20.00%
# Default in t = 1: -26.32%
# Default in t = 2: -14.96%
# Default in t = 3: -6.43%
# Default in t = 4: 0.00%
# Default in t = 5: 4.82%
#
# ...
# Running main analysis...
#
# Main Results:
# Interest Rate  Loan Life Initial Default Probability    IRR
#           30%          5                         10% 13.72%
#           30%          5                         20%  5.08%
#           30%          5                         30% -2.08%
#           30%         10                         10% 15.68%
#           30%         10                         20%  5.59%
#           30%         10                         30% -2.20%
#           30%         20                         10% 16.09%
#           30%         20                         20%  5.73%
#           30%         20                         30% -2.16%
# ...

# %% [raw]
# ## Survival Probability

# %% [raw]
# def calculate_survival_probabilities(default_probs):
#     """
#     Calculate the probability of surviving to each year (not defaulting before)
#     """
#     survival_probs = []
#     cumulative_survival = 1.0
#
#     for i, default_prob in enumerate(default_probs):
#         if i == 0:
#             # Probability of surviving year 1 = 1 - default_prob_1
#             survival_probs.append(1 - default_prob)
#             cumulative_survival = 1 - default_prob
#         else:
#             # Probability of surviving to year i+1 = surviving to year i * (1 - default_prob_i+1)
#             cumulative_survival = cumulative_survival * (1 - default_prob)
#             survival_probs.append(cumulative_survival)
#
#     return survival_probs

# %% [raw]
# ## Calculate Scenario IRR

# %% [raw]
# def calculate_scenario_irr(cash_flows, initial_investment):
#     """
#     Calculate IRR for a specific cash flow scenario
#     """
#     # Build the full cash‐flow series, with time 0 = -initial investment
#     series = [-initial_investment] + list(cash_flows)
#     irr = npf.irr(series)
#
#     return irr

# %% [raw]
# ## Calculate expected IRR

# %% [raw]
# def calculate_expected_irr_analytical(price_machine: int, life: int, interest_rate: float,
#                                     default_probs: List[float], recovery_rate: float) -> Dict:
#     """
#     Calculate expected IRR using analytical approach with expected values
#     """
#     scenarios = []
#
#     # Calculate survival probabilities
#     survival_probs = calculate_survival_probabilities(default_probs)
#
#     # Scenario 1: No default (survive all years)
#     no_default_prob = survival_probs[-1]  # Probability of surviving to the end
#
#     # Cash flows for no default scenario
#     no_default_cash_flows = [price_machine * interest_rate] * (life - 1)
#     no_default_cash_flows.append(price_machine * (1 + interest_rate))
#     no_default_irr = calculate_scenario_irr(no_default_cash_flows, price_machine)
#
#     scenarios.append({
#         'scenario': 'No Default',
#         'probability': no_default_prob,
#         'irr': no_default_irr,
#         'cash_flows': no_default_cash_flows
#     })
#
#     # Scenario 2-N: Default in each year
#     for default_year in range(1, life + 1):
#         # Probability of defaulting in this specific year
#         if default_year == 1:
#             default_year_prob = default_probs[0]
#         else:
#             # Probability = survive to year (default_year-1) * default in year default_year
#             survive_to_prev_year = survival_probs[default_year - 2] if default_year > 1 else 1.0
#             default_year_prob = survive_to_prev_year * default_probs[default_year - 1]
#
#         # Cash flows for default scenario
#         # Years 1 to default_year-1: regular interest payments
#         # Year default_year: 0 (default)
#         # Year default_year+1: 0 (bankruptcy process)
#         # Year default_year+2: recovery payment
#
#         default_cash_flows = []
#
#         # Regular payments before default
#         for year in range(1, default_year):
#             default_cash_flows.append(price_machine * interest_rate)
#
#         # Default year and year after: no payments
#         default_cash_flows.extend([0, 0])
#
#         # Recovery payment 2 years after default
#         recovery_payment = recovery_rate * price_machine
#         default_cash_flows.append(recovery_payment)
#
#         # Calculate IRR for this scenario
#         default_irr = calculate_scenario_irr(default_cash_flows, price_machine)
#
#         scenarios.append({
#             'scenario': f'Default in Year {default_year}',
#             'probability': default_year_prob,
#             'irr': default_irr,
#             'cash_flows': default_cash_flows
#         })
#
#     # Calculate expected IRR
#     expected_irr = sum(scenario['probability'] * scenario['irr'] for scenario in scenarios)
#
#     # Calculate overall default probability
#     total_default_prob = sum(scenario['probability'] for scenario in scenarios[1:])  # All except no default
#
#     return {
#         'expected_irr': expected_irr,
#         'scenarios': scenarios,
#         'total_default_probability': total_default_prob,
#         'no_default_probability': no_default_prob
#     }

# %% [raw]
# ## Calculate Default scenarios (FOR VERIFICATION PURPOSES)

# %% [raw]
# def calculate_specific_default_scenarios(inputs: ModelInputs) -> pd.DataFrame:
#     """
#     Calculate IRR for specific default scenarios (for verification purposes)
#     Base case: 5 years, 20% interest, 0.2 initial default
#     """
#     life = 5
#     interest_rate = 0.20  # 20% for verification
#     price_machine = inputs.price_machine
#     recovery_rate = inputs.recovery_rate
#     initial_default = 0.2
#
#     default_probs = calculate_default_probabilities(
#         initial_default, inputs.default_decay, inputs.final_default, life
#     )
#
#     scenarios = []
#
#     # No default scenario
#     cash_flows_no_default = [price_machine * interest_rate] * (life - 1)
#     cash_flows_no_default.append(price_machine * (1 + interest_rate))
#     irr_no_default = calculate_scenario_irr(cash_flows_no_default, price_machine)
#     scenarios.append(('No Default', irr_no_default * 100))
#
#     # Default scenarios for each year
#     for default_year in range(1, life + 1):
#         # Cash flows: regular payments before default, then 0, 0, recovery
#         cash_flows = []
#
#         # Regular payments before default
#         for year in range(1, default_year):
#             cash_flows.append(price_machine * interest_rate)
#
#         # Default year and year after: no payments
#         cash_flows.extend([0, 0])
#
#         # Recovery payment
#         cash_flows.append(recovery_rate * price_machine)
#
#         irr = calculate_scenario_irr(cash_flows, price_machine)
#         scenarios.append((f'Default in t = {default_year}', irr * 100))
#
#     return pd.DataFrame(scenarios, columns=['Scenario', 'IRR (%)'])

# %% [raw]
# ## FULL ANALYSIS

# %% [raw]
# def run_full_analysis(inputs: ModelInputs) -> pd.DataFrame:
#     """
#     Run the complete analysis for all parameter combinations using analytical approach
#     """
#     results = []
#
#     total_combinations = len(inputs.loan_life) * len(inputs.initial_default) * len(inputs.interest_rates)
#     current_run = 0
#
#     for life in inputs.loan_life:
#         for i, initial_default in enumerate(inputs.initial_default):
#             for interest_rate in inputs.interest_rates:
#                 current_run += 1
#                 print(f"Calculating scenario {current_run}/{total_combinations}: "
#                       f"Life={life}, Default={initial_default}, Rate={interest_rate:.0%}")
#
#                 # Calculate default probabilities for this scenario
#                 default_probs = calculate_default_probabilities(
#                     initial_default, inputs.default_decay, inputs.final_default, life
#                 )
#
#                 # Calculate expected IRR analytically
#                 result = calculate_expected_irr_analytical(
#                     inputs.price_machine, life, interest_rate, default_probs, inputs.recovery_rate
#                 )
#
#                 results.append({
#                     'Loan_Life': life,
#                     'Initial_Default_Prob': initial_default,
#                     'Default_Case': inputs.case_names[i],
#                     'Interest_Rate': interest_rate,
#                     'Expected_IRR': result['expected_irr'],
#                     'Default_Rate': result['total_default_probability'],
#                     'No_Default_Prob': result['no_default_probability']
#                 })
#
#     return pd.DataFrame(results)

# %% [raw]
# ## Detailed scenario analysis

# %% [raw]
# def create_detailed_scenario_analysis(inputs: ModelInputs, life: int = 5, initial_default: float = 0.2,
#                                     interest_rate: float = 0.35) -> pd.DataFrame:
#     """
#     Create detailed scenario breakdown for a specific case
#     """
#     default_probs = calculate_default_probabilities(
#         initial_default, inputs.default_decay, inputs.final_default, life
#     )
#
#     result = calculate_expected_irr_analytical(
#         inputs.price_machine, life, interest_rate, default_probs, inputs.recovery_rate
#     )
#
#     scenario_data = []
#     for scenario in result['scenarios']:
#         scenario_data.append({
#             'Scenario': scenario['scenario'],
#             'Probability': scenario['probability'],
#             'IRR': scenario['irr'],
#             'Weighted_IRR': scenario['probability'] * scenario['irr']
#         })
#
#     df = pd.DataFrame(scenario_data)
#     df['Probability_Pct'] = df['Probability'] * 100
#     df['IRR_Pct'] = df['IRR'] * 100
#     df['Weighted_IRR_Pct'] = df['Weighted_IRR'] * 100
#
#     return df

# %% [raw]
# ## VISUALIZATION

# %% [raw]
# def create_visualizations(results_df: pd.DataFrame):
#     """
#     Create comprehensive visualizations of the results
#     """
#     # Set up the plotting style
#     plt.style.use('default')
#     sns.set_palette("husl")
#
#     # Create a large figure with multiple subplots
#     fig = plt.figure(figsize=(20, 16))
#
#     # 1. Expected IRR by Interest Rate and Default Scenario
#     plt.subplot(3, 3, 1)
#     for case in results_df['Default_Case'].unique():
#         case_data = results_df[results_df['Default_Case'] == case]
#         avg_by_rate = case_data.groupby('Interest_Rate')['Expected_IRR'].mean()
#         plt.plot(avg_by_rate.index * 100, avg_by_rate.values * 100,
#                 marker='o', linewidth=2, label=case)
#     plt.xlabel('Interest Rate (%)')
#     plt.ylabel('Expected IRR (%)')
#     plt.title('Expected IRR vs Interest Rate by Default Scenario')
#     plt.legend()
#     plt.grid(True, alpha=0.3)
#
#     # 2. Expected IRR by Loan Life
#     plt.subplot(3, 3, 2)
#     for life in sorted(results_df['Loan_Life'].unique()):
#         life_data = results_df[results_df['Loan_Life'] == life]
#         avg_by_rate = life_data.groupby('Interest_Rate')['Expected_IRR'].mean()
#         plt.plot(avg_by_rate.index * 100, avg_by_rate.values * 100,
#                 marker='s', linewidth=2, label=f'{life} years')
#     plt.xlabel('Interest Rate (%)')
#     plt.ylabel('Expected IRR (%)')
#     plt.title('Expected IRR vs Interest Rate by Loan Life')
#     plt.legend()
#     plt.grid(True, alpha=0.3)
#
#     # 3. Heatmap of Expected IRR
#     pivot_data = results_df.pivot_table(
#         values='Expected_IRR',
#         index=['Loan_Life', 'Default_Case'],
#         columns='Interest_Rate'
#     )
#     plt.subplot(3, 3, 3)
#     sns.heatmap(pivot_data * 100, annot=True, fmt='.1f', cmap='RdYlGn')
#     plt.title('Expected IRR (%) Heatmap')
#
#     # 4. Default Rate Analysis
#     plt.subplot(3, 3, 4)
#     default_pivot = results_df.pivot_table(
#         values='Default_Rate',
#         index='Default_Case',
#         columns='Loan_Life'
#     )
#     sns.heatmap(default_pivot * 100, annot=True, fmt='.1f', cmap='Reds')
#     plt.title('Default Rate (%) by Scenario and Loan Life')
#
#     # 5. IRR Distribution by Default Case (for base case: 5 years, 35% interest)
#     plt.subplot(3, 3, 5)
#     base_case = results_df[(results_df['Loan_Life'] == 5) &
#                           (results_df['Interest_Rate'] == 0.35)]
#     x_pos = range(len(base_case))
#     colors = ['red', 'orange', 'green']
#     bars = plt.bar(x_pos, base_case['Expected_IRR'] * 100, color=colors)
#     plt.xlabel('Default Scenario')
#     plt.ylabel('Expected IRR (%)')
#     plt.title('Expected IRR by Default Scenario\n(5 years, 35% interest)')
#     plt.xticks(x_pos, base_case['Default_Case'], rotation=45)
#
#     # Add value labels on bars
#     for i, bar in enumerate(bars):
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
#                 f'{height:.1f}%', ha='center', va='bottom')
#
#     # 6. Risk-Return Scatter Plot
#     plt.subplot(3, 3, 6)
#     colors = ['red', 'orange', 'green']
#     for i, case in enumerate(results_df['Default_Case'].unique()):
#         case_data = results_df[results_df['Default_Case'] == case]
#         plt.scatter(case_data['Default_Rate'] * 100, case_data['Expected_IRR'] * 100,
#                    c=colors[i], s=60, alpha=0.7, label=case)
#     plt.xlabel('Default Rate (%)')
#     plt.ylabel('Expected IRR (%)')
#     plt.title('Risk-Return Profile')
#     plt.legend()
#     plt.grid(True, alpha=0.3)
#
#     # 7. Expected IRR vs Interest Rate (all combinations)
#     plt.subplot(3, 3, 7)
#     scatter = plt.scatter(results_df['Interest_Rate'] * 100, results_df['Expected_IRR'] * 100,
#                c=results_df['Loan_Life'], s=60, alpha=0.7, cmap='viridis')
#     plt.colorbar(scatter, label='Loan Life (years)')
#     plt.xlabel('Interest Rate (%)')
#     plt.ylabel('Expected IRR (%)')
#     plt.title('Expected IRR vs Interest Rate\n(colored by Loan Life)')
#     plt.grid(True, alpha=0.3)
#
#     # 8. Impact of Loan Life on Expected IRR
#     plt.subplot(3, 3, 8)
#     life_impact = results_df.groupby(['Loan_Life', 'Interest_Rate'])['Expected_IRR'].mean().unstack()
#     life_impact.plot(kind='bar', ax=plt.gca(), width=0.8)
#     plt.xlabel('Loan Life (years)')
#     plt.ylabel('Expected IRR (%)')
#     plt.title('Expected IRR by Loan Life and Interest Rate')
#     plt.legend(title='Interest Rate', labels=['30%', '35%', '40%'])
#     plt.xticks(rotation=0)
#
#     # 9. Summary Statistics Table
#     plt.subplot(3, 3, 9)
#     plt.axis('off')
#
#     # Create summary statistics
#     summary_stats = results_df.groupby('Default_Case')['Expected_IRR'].agg(['mean', 'std', 'min', 'max'])
#
#     summary_text = "Expected IRR Summary Statistics (%)\n" + "="*40 + "\n\n"
#     for case in results_df['Default_Case'].unique():
#         stats = summary_stats.loc[case]
#         summary_text += f"{case}:\n"
#         summary_text += f"  Mean: {stats['mean']*100:6.1f}%\n"
#         summary_text += f"  Std:  {stats['std']*100:6.1f}%\n"
#         summary_text += f"  Min:  {stats['min']*100:6.1f}%\n"
#         summary_text += f"  Max:  {stats['max']*100:6.1f}%\n\n"
#
#     # Add default rate summary
#     default_summary = results_df.groupby('Default_Case')['Default_Rate'].mean()
#     summary_text += "Average Default Rates:\n"
#     for case in results_df['Default_Case'].unique():
#         summary_text += f"  {case}: {default_summary[case]*100:.1f}%\n"
#
#     plt.text(0.05, 0.95, summary_text, fontsize=9, verticalalignment='top',
#              fontfamily='monospace', transform=plt.gca().transAxes)
#
#     plt.tight_layout()
#     plt.show()

# %% [raw]
# ## Results Table

# %% [raw]
# def create_results_table(results_df: pd.DataFrame) -> pd.DataFrame:
#     """
#     Create a formatted results table
#     """
#     # Pivot the results to create a comprehensive table
#     table = results_df.pivot_table(
#         values='Expected_IRR',
#         index=['Loan_Life', 'Default_Case'],
#         columns='Interest_Rate',
#         aggfunc='mean'
#     )
#
#     # Format as percentages
#     table = table * 100
#
#     return table

# %% [raw]
# def create_main_irr_dataframe(inputs: ModelInputs) -> pd.DataFrame:
#     """
#     Create the main IRR DataFrame with the required format:
#     ['Interest Rate', 'Loan Life', 'Initial Default Probability', 'IRR']
#     """
#     irr_data = []
#
#     for interest_rate in inputs.interest_rates:
#         for loan_life in inputs.loan_life:
#             for initial_default in inputs.initial_default:
#                 # Calculate default probabilities for this scenario
#                 default_probs = calculate_default_probabilities(
#                     initial_default, inputs.default_decay, inputs.final_default, loan_life
#                 )
#
#                 # Calculate expected IRR analytically
#                 result = calculate_expected_irr_analytical(
#                     inputs.price_machine, loan_life, interest_rate, default_probs, inputs.recovery_rate
#                 )
#
#                 irr_data.append({
#                     'Interest Rate': interest_rate,
#                     'Loan Life': loan_life,
#                     'Initial Default Probability': initial_default,
#                     'IRR': result['expected_irr']
#                 })
#
#     return pd.DataFrame(irr_data)
#
# def main():
#     """
#     Main execution function
#     """
#     print("Starting Probabilistic Loan Pricing Analysis (Analytical Approach)")
#     print("="*70)
#
#     # Initialize model inputs
#     inputs = ModelInputs()
#
#     print("Model Parameters:")
#     print(f"Machine Price: ${inputs.price_machine:,}")
#     print(f"Loan Lives: {inputs.loan_life} years")
#     print(f"Initial Default Probabilities: {inputs.initial_default}")
#     print(f"Interest Rates: {[f'{r:.0%}' for r in inputs.interest_rates]}")
#     print(f"Default Decay Rate: {inputs.default_decay}")
#     print(f"Final Year Default Probability: {inputs.final_default}")
#     print(f"Recovery Rate: {inputs.recovery_rate:.0%}")
#     print("="*70)
#
#     # Create the main IRR DataFrame as requested
#     print("\nCreating Main IRR DataFrame...")
#     irr_df = create_main_irr_dataframe(inputs)
#
#     print("\nMain IRR Results:")
#     print(irr_df.to_string(index=False, float_format=lambda x: f'{x:.4f}' if abs(x) < 1 else f'{x:.0f}'))
#
#     # Run verification scenarios first
#     print("\n" + "="*70)
#     print("Verification Scenarios (Base Case: 5 years, 20% interest, 20% initial default):")
#     verification_df = calculate_specific_default_scenarios(inputs)
#     print(verification_df.to_string(index=False, float_format=lambda x: f'{x:.2f}'))
#
#     # Show detailed scenario breakdown for base case
#     print("\n" + "="*70)
#     print("Detailed Scenario Analysis (5 years, 20% initial default, 35% interest):")
#     detailed_scenarios = create_detailed_scenario_analysis(inputs, 5, 0.2, 0.35)
#     print(detailed_scenarios[['Scenario', 'Probability_Pct', 'IRR_Pct', 'Weighted_IRR_Pct']].to_string(
#         index=False, float_format=lambda x: f'{x:.2f}'))
#     print(f"\nExpected IRR: {detailed_scenarios['Weighted_IRR_Pct'].sum():.2f}%")
#
#     # Run full analytical analysis for additional analysis
#     print("\n" + "="*70)
#     print("Running Full Analytical Analysis...")
#     results_df = run_full_analysis(inputs)
#
#     # Display results
#     print("\nDetailed Results Summary:")
#     results_table = create_results_table(results_df)
#     print("\nExpected IRR (%) by Loan Life, Default Case, and Interest Rate:")
#     print(results_table.round(2))
#
#     # Create visualizations
#     print("\nGenerating Visualizations...")
#     create_visualizations(results_df)
#
#     # Export results
#     irr_df.to_csv('irr_results.csv', index=False)
#     results_df.to_csv('loan_pricing_results_analytical.csv', index=False)
#     verification_df.to_csv('verification_scenarios.csv', index=False)
#     print("\nResults exported to:")
#     print("- 'irr_results.csv' (Main IRR DataFrame)")
#     print("- 'loan_pricing_results_analytical.csv' (Detailed Results)")
#     print("- 'verification_scenarios.csv' (Verification)")
#
#     print("\nAnalytical Analysis Complete!")
#     print("="*70)
#
#     return irr_df, results_df, results_table, verification_df
#
# # Run the analysis and create the main IRR DataFrame
# if __name__ == "__main__":
#     irr_df, results_df, results_table, verification_df = main()
#
#     # Display the main IRR DataFrame in the requested format
#     print("\n" + "="*70)
#     print("MAIN IRR DATAFRAME (irr_df):")
#     print("="*70)
#     print(irr_df.to_string(index=False, formatters={
#         'Interest Rate': lambda x: f'{x:.0%}',
#         'Loan Life': lambda x: f'{x:.0f}',
#         'Initial Default Probability': lambda x: f'{x:.1%}',
#         'IRR': lambda x: f'{x:.4f}'
#     }))
#
#     print(f"\nDataFrame Shape: {irr_df.shape}")
#     print(f"Total Scenarios: {len(irr_df)}")
#
#     # Show summary statistics
#     print("\nSummary Statistics for IRR:")
#     print(f"Mean IRR: {irr_df['IRR'].mean():.4f} ({irr_df['IRR'].mean():.2%})")
#     print(f"Min IRR:  {irr_df['IRR'].min():.4f} ({irr_df['IRR'].min():.2%})")
#     print(f"Max IRR:  {irr_df['IRR'].max():.4f} ({irr_df['IRR'].max():.2%})")
#     print(f"Std IRR:  {irr_df['IRR'].std():.4f} ({irr_df['IRR'].std():.2%})")
#
#     # Show a few examples
#     print("\nExample rows:")
#     print("Lowest IRR scenarios:")
#     print(irr_df.nsmallest(3, 'IRR').to_string(index=False, formatters={
#         'Interest Rate': lambda x: f'{x:.0%}',
#         'Loan Life': lambda x: f'{x:.0f}',
#         'Initial Default Probability': lambda x: f'{x:.1%}',
#         'IRR': lambda x: f'{x:.4f} ({x:.2%})'
#     }))
#
#     print("\nHighest IRR scenarios:")
#     print(irr_df.nlargest(3, 'IRR').to_string(index=False, formatters={
#         'Interest Rate': lambda x: f'{x:.0%}',
#         'Loan Life': lambda x: f'{x:.0f}',
#         'Initial Default Probability': lambda x: f'{x:.1%}',
#         'IRR': lambda x: f'{x:.4f} ({x:.2%})'
#     }))

# %% [raw]
# # Main answer should be a DataFrame with columns of ['Interest Rate', 'Loan Life', 'Initial Default Probability', 'IRR']
# # The IRR is the expected IRR across all the default cases for the interest rate,
# # loan life, and initial default probability in that row
# # Be sure to save this into irr_df
